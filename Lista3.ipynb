# %% [markdown]
# <a href="https://colab.research.google.com/github/deboracarolinags/Eng1111_deb/blob/main/Lista3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Questão 1:

# %%
import pandas as pd

from google.colab import  drive

drive.mount('/drive',force_remount=True)

dados = pd.read_csv("/drive/My Drive/Eng1111/class_bank_marketing.csv")

dados = pd.DataFrame(dados)

display(dados)
# Out:
# Mounted at /drive
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# Questão 2:

# %%
print(dados.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB
# None

# %% [markdown]
# Questão 3:

# %%
dados['balance'].dropna(axis=0)
display(dados)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# Questão 4:

# %%
import numpy as np
media=np.mean(dados['duration'])
print(media)
# Out:
# 263.96129174961294

# %% [markdown]
# Questão 5:

# %%
eliminar=dados['duration']>media/15 # maior q 15% eliminado
outros=dados[eliminar]
display(outros)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# Questão 6:

# %%
outros2=outros.copy()
outros2.drop(columns=['age','job','marital','housing','loan','contact','default','day','pdays','y','month','previous'],axis=1,inplace=True)
display(outros2)
# Out:
#       education  balance  duration  campaign poutcome
# 0       primary     1787        79         1  unknown
# 1     secondary     4789       220         1  failure
# 2      tertiary     1350       185         1  failure
# 3      tertiary     1476       199         4  unknown
# 4     secondary        0       226         1  unknown
# ...         ...      ...       ...       ...      ...
# 4516  secondary     -333       329         5  unknown
# 4517   tertiary    -3313       153         1  unknown
# 4518  secondary      295       151        11  unknown
# 4519  secondary     1137       129         4    other
# 4520   tertiary     1136       345         2    other
#
# [4417 rows x 5 columns]

# %% [markdown]
# Questão 7:

# %%
import random
outros.insert(1,'colunaNova',((outros['duration']-outros['campaign'])*random.randint(0,1)).astype(int))
display(outros)
# Out:
#       age  colunaNova            job  marital  education default  balance  \
# 0      30           0     unemployed  married    primary      no     1787
# 1      33           0       services  married  secondary      no     4789
# 2      35           0     management   single   tertiary      no     1350
# 3      30           0     management  married   tertiary      no     1476
# 4      59           0    blue-collar  married  secondary      no        0
# ...   ...         ...            ...      ...        ...     ...      ...
# 4516   33           0       services  married  secondary      no     -333
# 4517   57           0  self-employed  married   tertiary     yes    -3313
# 4518   57           0     technician  married  secondary      no      295
# 4519   28           0    blue-collar  married  secondary      no     1137
# 4520   44           0   entrepreneur   single   tertiary      no     1136
#
#      housing loan   contact  day month  duration  campaign  pdays  previous  \
# ...

# %% [markdown]
# Questão 8:

# %%
outros=outros.reindex(np.random.permutation(outros.index))
display(outros)
# Out:
#       age  colunaNova            job  marital  education default  balance  \
# 1766   45           0     technician  married  secondary      no     1415
# 4518   57           0     technician  married  secondary      no      295
# 1845   27           0       services   single  secondary      no      261
# 2661   57           0        retired  married    primary      no     1238
# 2883   46           0  self-employed  married   tertiary      no     1148
# ...   ...         ...            ...      ...        ...     ...      ...
# 274    35           0    blue-collar   single   tertiary      no        0
# 2250   50           0     management  married   tertiary      no      207
# 1270   30           0         admin.  married  secondary      no      122
# 580    29           0     management  married   tertiary      no      361
# 387    48           0     technician  married  secondary      no      302
#
#      housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %% [markdown]
# Questão 9:

# %%
outros=outros.sort_values(by='age', ascending=False) #ordem descrescente
display(outros)
# Out:
#       age  colunaNova      job   marital  education default  balance housing  \
# 3311   87           0  retired   married    primary      no      230      no
# 1866   86           0  retired   married  secondary      no     1503      no
# 4108   84           0  retired  divorced    primary      no      639      no
# 4388   83           0  retired  divorced    primary      no     1097      no
# 1349   83           0  retired   married    primary      no      425      no
# ...   ...         ...      ...       ...        ...     ...      ...     ...
# 999    20           0  student    single  secondary      no      291      no
# 3233   19           0  student    single    unknown      no     1169      no
# 1900   19           0  student    single    unknown      no        0      no
# 503    19           0  student    single    primary      no      103      no
# 2780   19           0  student    single  secondary      no      302      no
#
# ...

# %% [markdown]
# Questão 10:

# %%
agrupamento = outros.groupby(['age','contact']).count()
print(agrupamento)
# Out:
#                colunaNova  job  marital  education  default  balance  housing  \
# age contact
# 19  cellular            4    4        4          4        4        4        4
# 20  cellular            2    2        2          2        2        2        2
#     telephone           1    1        1          1        1        1        1
# 21  cellular            2    2        2          2        2        2        2
#     telephone           1    1        1          1        1        1        1
# ...                   ...  ...      ...        ...      ...      ...      ...
# 83  cellular            1    1        1          1        1        1        1
#     telephone           3    3        3          3        3        3        3
# 84  telephone           1    1        1          1        1        1        1
# 86  telephone           1    1        1          1        1        1        1
# 87  cellular            1    1        1          1        1        1        1
#
# ...

# %% [markdown]
# Questão 11:

# %%
#criei uma nova coluna multiplicando a idade por 2
def receba(idade):
  return idade*2
outros['novaidade']=list(map(receba,outros['age']))
print(outros)
# Out:
#       age  colunaNova            job  marital  education default  balance  \
# 0      30           0     unemployed  married    primary      no     1787
# 1      33           0       services  married  secondary      no     4789
# 2      35           0     management   single   tertiary      no     1350
# 3      30           0     management  married   tertiary      no     1476
# 4      59           0    blue-collar  married  secondary      no        0
# ...   ...         ...            ...      ...        ...     ...      ...
# 4516   33           0       services  married  secondary      no     -333
# 4517   57           0  self-employed  married   tertiary     yes    -3313
# 4518   57           0     technician  married  secondary      no      295
# 4519   28           0    blue-collar  married  secondary      no     1137
# 4520   44           0   entrepreneur   single   tertiary      no     1136
#
#      housing loan   contact  day month  duration  campaign  pdays  previous  \
# ...

# %% [markdown]
# Questão 12:

# %%
from google.colab import drive
drive.mount ("/drive", force_remount=True)
outros.to_csv('/drive/MyDrive/Eng1111/novoarquivoClass_Bank_Marketing.csv')
# Out:
# Mounted at /drive

# %% [markdown]
# Questão 13:

# %%
import json
from google.colab import drive
drive.mount ("/drive", force_remount=True)
outros.to_json('/drive/MyDrive/Eng1111/novoarquivoClass_Bank_Marketing.json')
# Out:
# Mounted at /drive

# %% [markdown]
# Questão 14: enviada pro github
